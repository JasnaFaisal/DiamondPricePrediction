# %% [markdown]
# ### Introduction About the Data :
#
# **The dataset** The goal is to predict `price` of given diamond (Regression Analysis).
#
# There are 10 independent variables (including `id`):
#
# * `id` : unique identifier of each diamond
# * `carat` : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# * `cut` : Quality of Diamond Cut
# * `color` : Color of Diamond
# * `clarity` : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# * `depth` : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# * `table` : A diamond's table is the facet which can be seen when the stone is viewed face up.
# * `x` : Diamond X dimension
# * `y` : Diamond Y dimension
# * `x` : Diamond Z dimension
#
# Target variable:
# * `price`: Price of the given Diamond.
#
# Dataset Source Link :
# [https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv](https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv)

# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ### There are no missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.describe()
# Out:
#                   id          carat          depth          table  \
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean    96786.000000       0.790688      61.820574      57.227675
# std     55879.856166       0.462688       1.081704       1.918844
# min         0.000000       0.200000      52.100000      49.000000
# 25%     48393.000000       0.400000      61.300000      56.000000
# 50%     96786.000000       0.700000      61.900000      57.000000
# 75%    145179.000000       1.030000      62.400000      58.000000
# max    193572.000000       3.500000      71.600000      79.000000
#
#                    x              y              z          price
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        5.715312       5.720094       3.534246    3969.155414
# std         1.109422       1.102333       0.688922    4034.374138
# min         0.000000       0.000000       0.000000     326.000000
# ...

# %%
## Lets drop the id column
df=df.drop(labels=['id'],axis=1)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## check for duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
## segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Categorical Columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plot_count=1
plt.figure(figsize=(20,15))
x=0
for i in numerical_columns:
    if plot_count<len(numerical_columns):
        plt.subplot(3,2,plot_count)
        sns.histplot(data=df,x=i,kde=True)
        plt.xlabel(i,fontsize=20)
    plot_count+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,15))
pie_count=1
for i in categorical_columns:
    if (pie_count<=len(categorical_columns)):
        array=df[i].value_counts()
        label=df[i].value_counts().index
        plt.subplot(1,3,pie_count)
        array.plot(kind='pie',labels=label,autopct='%1.1f%%',fontsize=20,shadow=True)
    pie_count+=1
plt.tight_layout()
plt.show()

# %%
## correlation
sns.heatmap(df[numerical_columns].corr(),linewidth=0.3,vmin=-0.7,vmax=0.7,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From the heat map,we can see that price is highly correlated with z,y,x and hence we can drop those columns.

# %%
#curr
#df.drop(['x','y','z'],axis=1)

# %%
df.groupby('price')[['carat','depth','x','y','z']].mean().plot(figsize=(20,10))
plt.title('Line plot showing variations of different carat and depth over price',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.xticks(rotation=45)
plt.title('Cut Vs Clarity',fontsize=20)
ax=sns.countplot(data=df,x='cut',hue='clarity')

plt.subplot(1,3,2)
plt.xticks(rotation=45)
plt.title('Cut Vs Color',fontsize=20)
ax=sns.countplot(data=df,x='cut',hue='color')  

plt.subplot(1,3,3)
plt.xticks(rotation=45)
plt.title('Clarity Vs Color',fontsize=20)
ax=sns.countplot(data=df,x='clarity',hue='color') 

plt.tight_layout()
plt.show()

# %%
df2=df[numerical_columns]

# %%
sns.pairplot(df2)

# %%
#giving ranks to cut,clarity and color based on the domain knowledge
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

df['cut']=df['cut'].map(cut_map)
df['clarity'] = df['clarity'].map(clarity_map)
df['color'] = df['color'].map(color_map)

# %%
#checking for outliers
plt.figure(figsize=(20,10))
plt.xticks(rotation=90,fontsize=15)
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# no significant outliers present
